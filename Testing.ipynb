# %%
# %load_ext autoreload
# %autoreload 2
from ExampleSceneDef import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
im = c2().render(output_shape = [720, 1280])
# 144, 256
# 432, 768
# 720, 1280
im.show()

# %%
im = c2().render(output_shape = [144, 256])
# 144, 256
# 432, 768
# 720, 1280
im.show()

# %% [markdown]
# ### Step 0
# When you have completed Step 0 your the image below should look like:
# ![Step0](./ref/step0.png)

# %%
im = OrthoFriendlyExample().render()
im.show()
# im.writeToFile("OrthoFriendlyExample.png")

# %% [markdown]
# ### Step 1
# When you have completed Step 0 your the image below should look like:
# ![Step1](./ref/step1.png)

# %%
im = TwoSpheresExample().render(output_shape = [144,256])
im.show()

ref = Image(path="./ref/step1.png").GetFloatCopy();
ref.show()
print("Max diff with reference is {}".format(np.abs(ref.pixels*255-im.pixels).max()))
# Out:
# Max diff with reference is 0.0

# %% [markdown]
# ### Step 2-7
# See the [assignment docs](https://www.cs.cornell.edu/courses/cs4620/2023fa/assignments/docs/category/assignment-4)

# %%
im = TwoSpheresExample().render(output_shape = [144,256])
im.show()

# %%
im = ThreeSpheresExample().render(output_shape = [144,256], gamma_correct=True)
im.show()

ref = Image(path="./ref/step7.png").GetFloatCopy();
ref.show()
print("Max diff with reference is {}".format(np.abs(ref.pixels*255-im.pixels).max()))
# Out:
# Max diff with reference is 5.0

# %%
im = CubeExample().render(output_shape = [144,256])
im.show()

ref = Image(path="./ref/step6.png").GetFloatCopy();
ref.show()
print("Max diff with reference is {}".format(np.abs(ref.pixels*255-im.pixels).max()))
# Out:
# Max diff with reference is 2.842170943040401e-14
